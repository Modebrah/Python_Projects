# %%
#importing libraries

import numpy as np
import pandas as pd

# %%
#importing dataset
df=pd.read_csv("Dog_Conditions.csv")

# %%
df
# Out:
#     AnimalName                        symptoms1             symptoms2  \
# 0          Dog                            Fever              Diarrhea
# 1          Dog                            Fever              Diarrhea
# 2          Dog                            Fever              Diarrhea
# 3          Dog                            Fever  Difficulty breathing
# 4          Dog                            Fever              Diarrhea
# ..         ...                              ...                   ...
# 866  Buffaloes                            Fever  Difficulty breathing
# 867  Buffaloes                            Fever     Loss of  appetite
# 868  Buffaloes      Lesions in the nasal cavity       Lesions on nose
# 869  Buffaloes                        Hair loss              Dandruff
# 870  Buffaloes  Greenish-yellow nasal discharge  Lack of pigmentation
#
#                symptoms3             symptoms4           symptoms5 Dangerous
# ...

# %%
df.head()
# Out:
#   AnimalName symptoms1             symptoms2 symptoms3    symptoms4  \
# 0        Dog     Fever              Diarrhea  Vomiting  Weight loss
# 1        Dog     Fever              Diarrhea  Coughing    Tiredness
# 2        Dog     Fever              Diarrhea  Coughing     Vomiting
# 3        Dog     Fever  Difficulty breathing  Coughing     Lethargy
# 4        Dog     Fever              Diarrhea  Coughing     Lethargy
#
#      symptoms5 Dangerous
# 0  Dehydration       Yes
# 1        Pains       Yes
# 2     Anorexia       Yes
# 3     Sneezing       Yes
# 4     Blue Eye       Yes

# %%
df.tail()
# Out:
#     AnimalName                        symptoms1             symptoms2  \
# 866  Buffaloes                            Fever  Difficulty breathing
# 867  Buffaloes                            Fever     Loss of  appetite
# 868  Buffaloes      Lesions in the nasal cavity       Lesions on nose
# 869  Buffaloes                        Hair loss              Dandruff
# 870  Buffaloes  Greenish-yellow nasal discharge  Lack of pigmentation
#
#                symptoms3             symptoms4           symptoms5 Dangerous
# 866        Poor Appetite   Eye and Skin change  Unable to exercise       Yes
# 867  Lession on the skin              Lethargy          Joint Pain       Yes
# 868             Vomiting       Noisy Breathing     Lesions on nose       Yes
# 869             Vomiting  Crusting of the skin      Ulcerated skin       Yes
# 870             Vomiting              Lethargy        Pain on face       Yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 871 entries, 0 to 870
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   AnimalName  871 non-null    object
#  1   symptoms1   871 non-null    object
#  2   symptoms2   871 non-null    object
#  3   symptoms3   871 non-null    object
#  4   symptoms4   871 non-null    object
#  5   symptoms5   871 non-null    object
#  6   Dangerous   869 non-null    object
# dtypes: object(7)
# memory usage: 47.8+ KB

# %%
df.describe()
# Out:
#        AnimalName symptoms1 symptoms2 symptoms3    symptoms4 symptoms5  \
# count         871       871       871       871          871       871
# unique         46       232       230       229          217       203
# top     Buffaloes     Fever  Diarrhea  Coughing  Weight loss     Pains
# freq          129       257       119        95          117        99
#
#        Dangerous
# count        869
# unique         2
# top          Yes
# freq         849

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 866    False
# 867    False
# 868    False
# 869    False
# 870    False
# Length: 871, dtype: bool

# %%
df.isnull().sum()
# Out:
# AnimalName    0
# symptoms1     0
# symptoms2     0
# symptoms3     0
# symptoms4     0
# symptoms5     0
# Dangerous     2
# dtype: int64

# %%
sum(df.duplicated())
# Out:
# 28

# %%
df.describe()
# Out:
#        AnimalName symptoms1 symptoms2 symptoms3    symptoms4 symptoms5  \
# count         871       871       871       871          871       871
# unique         46       232       230       229          217       203
# top     Buffaloes     Fever  Diarrhea  Coughing  Weight loss     Pains
# freq          129       257       119        95          117        99
#
#        Dangerous
# count        869
# unique         2
# top          Yes
# freq         849

# %%
dfs = df.drop_duplicates()

# %%
dfs
# Out:
#     AnimalName                        symptoms1             symptoms2  \
# 0          Dog                            Fever              Diarrhea
# 1          Dog                            Fever              Diarrhea
# 2          Dog                            Fever              Diarrhea
# 3          Dog                            Fever  Difficulty breathing
# 4          Dog                            Fever              Diarrhea
# ..         ...                              ...                   ...
# 866  Buffaloes                            Fever  Difficulty breathing
# 867  Buffaloes                            Fever     Loss of  appetite
# 868  Buffaloes      Lesions in the nasal cavity       Lesions on nose
# 869  Buffaloes                        Hair loss              Dandruff
# 870  Buffaloes  Greenish-yellow nasal discharge  Lack of pigmentation
#
#                symptoms3             symptoms4           symptoms5 Dangerous
# ...

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 843 entries, 0 to 870
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   AnimalName  843 non-null    object
#  1   symptoms1   843 non-null    object
#  2   symptoms2   843 non-null    object
#  3   symptoms3   843 non-null    object
#  4   symptoms4   843 non-null    object
#  5   symptoms5   843 non-null    object
#  6   Dangerous   841 non-null    object
# dtypes: object(7)
# memory usage: 52.7+ KB

# %%
dfs.describe()
# Out:
#        AnimalName symptoms1 symptoms2 symptoms3    symptoms4 symptoms5  \
# count         843       843       843       843          843       843
# unique         46       232       230       229          217       203
# top     Buffaloes     Fever  Diarrhea  Coughing  Weight loss     Pains
# freq          129       257       119        95          116        83
#
#        Dangerous
# count        841
# unique         2
# top          Yes
# freq         821

# %%
dfs[dfs.duplicated()]
# Out:
# Empty DataFrame
# Columns: [AnimalName, symptoms1, symptoms2, symptoms3, symptoms4, symptoms5, Dangerous]
# Index: []

# %%
df[df.duplicated()]
# Out:
#     AnimalName                symptoms1         symptoms2  \
# 772      Tiger  Fetopelvic dispropotion    Uteria inertia
# 773      Tiger  Fetopelvic dispropotion    Uteria inertia
# 774      Tiger  Fetopelvic dispropotion    Uteria inertia
# 775      Tiger  Fetopelvic dispropotion    Uteria inertia
# 776      Tiger  Fetopelvic dispropotion    Uteria inertia
# 777      Tiger  Fetopelvic dispropotion    Uteria inertia
# 778      Tiger  Fetopelvic dispropotion    Uteria inertia
# 779      Tiger  Fetopelvic dispropotion    Uteria inertia
# 780      Tiger  Fetopelvic dispropotion    Uteria inertia
# 781      Tiger  Fetopelvic dispropotion    Uteria inertia
# 782      Tiger  Fetopelvic dispropotion    Uteria inertia
# 784     Donkey  Fetopelvic dispropotion    Uteria inertia
# 785     Donkey  Fetopelvic dispropotion    Uteria inertia
# 786     Donkey  Fetopelvic dispropotion    Uteria inertia
# 787     Donkey  Fetopelvic dispropotion    Uteria inertia
# ...

# %%
df[df.duplicated()]
# Out:
#     AnimalName                symptoms1         symptoms2  \
# 772      Tiger  Fetopelvic dispropotion    Uteria inertia
# 773      Tiger  Fetopelvic dispropotion    Uteria inertia
# 774      Tiger  Fetopelvic dispropotion    Uteria inertia
# 775      Tiger  Fetopelvic dispropotion    Uteria inertia
# 776      Tiger  Fetopelvic dispropotion    Uteria inertia
# 777      Tiger  Fetopelvic dispropotion    Uteria inertia
# 778      Tiger  Fetopelvic dispropotion    Uteria inertia
# 779      Tiger  Fetopelvic dispropotion    Uteria inertia
# 780      Tiger  Fetopelvic dispropotion    Uteria inertia
# 781      Tiger  Fetopelvic dispropotion    Uteria inertia
# 782      Tiger  Fetopelvic dispropotion    Uteria inertia
# 784     Donkey  Fetopelvic dispropotion    Uteria inertia
# 785     Donkey  Fetopelvic dispropotion    Uteria inertia
# 786     Donkey  Fetopelvic dispropotion    Uteria inertia
# 787     Donkey  Fetopelvic dispropotion    Uteria inertia
# ...

# %%
df[df["AnimalName"]=="Tiger"]
# Out:
#     AnimalName                symptoms1       symptoms2            symptoms3  \
# 410      Tiger        feline infections   lymphosarcoma  difficulty breating
# 767      Tiger          Wether restless         Kicking      Normal appetite
# 768      Tiger      Inability to stand    Pains to Walk           Depression
# 769      Tiger                    Fever         Succumb             Sluggish
# 770      Tiger                 Listless      Bottle jaw      Malpresentation
# 771      Tiger  Fetopelvic dispropotion  Uteria inertia      Malpresentation
# 772      Tiger  Fetopelvic dispropotion  Uteria inertia      Malpresentation
# 773      Tiger  Fetopelvic dispropotion  Uteria inertia      Malpresentation
# 774      Tiger  Fetopelvic dispropotion  Uteria inertia      Malpresentation
# 775      Tiger  Fetopelvic dispropotion  Uteria inertia      Malpresentation
# 776      Tiger  Fetopelvic dispropotion  Uteria inertia      Malpresentation
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.dtypes
# Out:
# AnimalName    object
# symptoms1     object
# symptoms2     object
# symptoms3     object
# symptoms4     object
# symptoms5     object
# Dangerous     object
# dtype: object

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 list().df.columns
#
# AttributeError: 'list' object has no attribute 'df'

# %%
df["AnimalName"]
# Out:
# 0            Dog
# 1            Dog
# 2            Dog
# 3            Dog
# 4            Dog
#          ...
# 866    Buffaloes
# 867    Buffaloes
# 868    Buffaloes
# 869    Buffaloes
# 870    Buffaloes
# Name: AnimalName, Length: 843, dtype: object

# %%
df["symptoms1"]
# Out:
# 0                                Fever
# 1                                Fever
# 2                                Fever
# 3                                Fever
# 4                                Fever
#                     ...
# 866                              Fever
# 867                              Fever
# 868        Lesions in the nasal cavity
# 869                          Hair loss
# 870    Greenish-yellow nasal discharge
# Name: symptoms1, Length: 843, dtype: object

# %%
df["Dangerous"] = df["Dangerous"].astype("category")

# %%
df.dtypes
# Out:
# AnimalName      object
# symptoms1       object
# symptoms2       object
# symptoms3       object
# symptoms4       object
# symptoms5       object
# Dangerous     category
# dtype: object
